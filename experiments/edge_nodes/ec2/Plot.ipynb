# %%
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from matplotlib.lines import Line2D
from plot_style import *
from flox.flock import Flock

# %%
df = pd.read_feather("edge_run.rounds_10.feather")
df["training_end"] = pd.to_datetime(df.training_end, format="%H:%M:%S")
df.head()
# Out:
#    train/acc  train/loss  train/epoch  train/batch_idx  \
# 0    0.03125    2.288605            0                0
# 1    0.03125    2.300116            0                1
# 2    0.06250    2.292505            0                2
# 3    0.15625    2.286013            0                3
# 4    0.09375    2.297627            0                4
#
#                   train/time             training_start  \
# 0 2024-04-02 22:10:58.234050 2024-04-02 22:10:23.309424
# 1 2024-04-02 22:10:58.247514 2024-04-02 22:10:23.309424
# 2 2024-04-02 22:10:58.260596 2024-04-02 22:10:23.309424
# 3 2024-04-02 22:10:58.273637 2024-04-02 22:10:23.309424
# 4 2024-04-02 22:10:58.286880 2024-04-02 22:10:23.309424
#
#                 training_end   node/idx node/kind parent/idx parent/kind  \
# 0 2024-04-02 22:11:20.157853  worker2.1    worker       agg2  aggregator
# 1 2024-04-02 22:11:20.157853  worker2.1    worker       agg2  aggregator
# 2 2024-04-02 22:11:20.157853  worker2.1    worker       agg2  aggregator
# 3 2024-04-02 22:11:20.157853  worker2.1    worker       agg2  aggregator
# 4 2024-04-02 22:11:20.157853  worker2.1    worker       agg2  aggregator
#
#    round  test/acc  test/loss  train/rel_time
# 0      0       0.1   2.304467    18041.431472
# 1      0       0.1   2.304467    18041.444936
# 2      0       0.1   2.304467    18041.458018
# 3      0       0.1   2.304467    18041.471059
# 4      0       0.1   2.304467    18041.484302

# %%
sns.lineplot(
    df,
    x="round",
    y="test/acc",
)
plt.xlabel("Round")
plt.ylabel("Test Accuracy")
plt.savefig("test_acc.pdf", bbox_inches="tight")
plt.show()

# %%
# sns.lineplot(
#     df,
#     x="train/time",
#     y="train/acc",
#     hue="node/idx",
#     errorbar=None,
# )
# plt.xlabel("Time")
# plt.ylabel("Train Accuracy")
# plt.savefig("test_acc_by_worker.pdf", bbox_inches="tight")
# plt.show()

# %%
test_acc = df.query("round == 9")["test/acc"].unique().item()
plt.axhline(test_acc)
plt.show()

# %%
# sns.lineplot(
#     df.query("`train/epoch` == 4"),
#     x="train/time",
#     y="train/acc",
#     hue="parent/idx",
#     errorbar=None,
# )
# plt.xlabel("Time")
# plt.ylabel("Train Accuracy")
# plt.savefig("test_acc_by_aggr.pdf", bbox_inches="tight")
# plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(5, 3.75), sharex=True)

# Per-worker
i = 0
sns.lineplot(
    df,
    x="training_start",
    y="train/acc",
    hue="node/idx",
    ax=axes[i],
)

# Get the x-ticks and -labels and then show the labels by minute instead of date.
# ticks = axes[i].get_xticks()
# labels = axes[i].get_xticklabels()
# labels = ["{}m".format(l.get_text().split()[-1].split(":")[-1]) for l in labels]
# axes[i].set_xticks(ticks, labels, rotation=0)

axes[i].set_xlabel("Time", weight="bold")
axes[i].set_ylabel("Train Accuracy", weight="bold")
legend = axes[i].legend(title="Worker ID", ncols=2, fancybox=False, edgecolor="k", frameon=False)
plt.setp(legend.get_title(), weight="bold")
# axes[i].axhline(test_acc, linestyle="--", color="k", linewidth=2)
# axes[i].text(ticks[0], 0.9, "Test Acc.", weight="bold", color="k")

# Per-aggr.
i = 1
sns.lineplot(
    df,
    x="training_start",
    y="train/acc",
    hue="parent/idx",
    style="parent/idx",
    ax=axes[i],
)

sns.lineplot(
    df,
    x="training_start",
    y="test/acc",
    linestyle="-.",
    color="black",
    ax=axes[1]
)

# Get the x-ticks and -labels and then show the labels by minute instead of date.
ticks = axes[i].get_xticks()
labels = axes[i].get_xticklabels()
labels = ["{}m".format(l.get_text().split()[-1].split(":")[-1]) for l in labels]

axes[i].set_xticks(ticks, labels, rotation=0)
axes[i].set_xlabel("Time", weight="bold")
axes[i].set_ylabel("Train Acc.", weight="bold")

handles, labels = axes[i].get_legend_handles_labels()
handles.extend([Line2D([0], [0], label="coord (Test Acc.)", color="black", linestyle="-.")])

legend = axes[i].legend(title="Aggregator ID", fancybox=False, edgecolor="k", frameon=False, handles=handles)

plt.setp(legend.get_title(), weight="bold")
# axes[i].axhline(test_acc, linestyle="--", color="k", linewidth=2)
# axes[i].text(ticks[0], 0.9, "Test Acc.", weight="bold", color="k")
axes[i].set_ylabel("Train Acc.", weight="bold")

plt.tight_layout()
plt.savefig("ec2_acc.pdf", bbox_inches="tight")
plt.show()

# %%
sns.lineplot(
    df,
    x="training_start",
    y="test/acc",
)
plt.show()

# %%
sns.lineplot(
    df,
    x="train/rel_time",
    y="train/acc",
)
plt.show()

# %%
ts = df.training_start.iloc[0]

# %%
dir(ts)
# Out:
# ['__add__',
#  '__array_priority__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_cython__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__setstate_cython__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_creso',
#  '_date_repr',
#  '_from_dt64',
#  '_from_value_and_reso',
#  '_repr_base',
#  '_round',
#  '_time_repr',
#  '_value',
#  'as_unit',
#  'asm8',
#  'astimezone',
#  'ceil',
#  'combine',
#  'ctime',
#  'date',
#  'day',
#  'day_name',
#  'day_of_week',
#  'day_of_year',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'dst',
#  'floor',
#  'fold',
#  'fromisocalendar',
#  'fromisoformat',
#  'fromordinal',
#  'fromtimestamp',
#  'hour',
#  'is_leap_year',
#  'is_month_end',
#  'is_month_start',
#  'is_quarter_end',
#  'is_quarter_start',
#  'is_year_end',
#  'is_year_start',
#  'isocalendar',
#  'isoformat',
#  'isoweekday',
#  'max',
#  'microsecond',
#  'min',
#  'minute',
#  'month',
#  'month_name',
#  'nanosecond',
#  'normalize',
#  'now',
#  'quarter',
#  'replace',
#  'resolution',
#  'round',
#  'second',
#  'strftime',
#  'strptime',
#  'time',
#  'timestamp',
#  'timetuple',
#  'timetz',
#  'to_datetime64',
#  'to_julian_date',
#  'to_numpy',
#  'to_period',
#  'to_pydatetime',
#  'today',
#  'toordinal',
#  'tz',
#  'tz_convert',
#  'tz_localize',
#  'tzinfo',
#  'tzname',
#  'unit',
#  'utcfromtimestamp',
#  'utcnow',
#  'utcoffset',
#  'utctimetuple',
#  'value',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
ts.strftime("%M:%S")
# Out:
# '10:23'

# %%
sns.kdeplot(df, x="training_end_diff")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 sns.kdeplot(df, x="training_end_diff")
#       2 plt.show()
#
# File ~/miniconda3/envs/flox-experiments/lib/python3.11/site-packages/seaborn/distributions.py:1679, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1676 if ax is None:
#    1677     ax = plt.gca()
# -> 1679 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1681 method = ax.fill_between if fill else ax.plot
#    1682 color = _default_color(method, hue, color, kwargs)
#
# File ~/miniconda3/envs/flox-experiments/lib/python3.11/site-packages/seaborn/_base.py:1084, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1079     if var_type not in allowed_types:
#    1080         err = (
#    1081             f"The {var} variable is {var_type}, but one of "
#    1082             f"{allowed_types} is required"
#    1083         )
# -> 1084         raise TypeError(err)
#    1086 # -- Get axis objects for each row in plot_data for type conversions and scaling
#    1088 facet_dim = {"x": "col", "y": "row"}
#
# TypeError: The x variable is categorical, but one of ['numeric', 'datetime'] is required

# %%
df.training_end_diff.dtype
# Out:
# dtype('<m8[us]')
