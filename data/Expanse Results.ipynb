# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_feather("expanse_results/kyle_results.feather")
df.head()
# Out:
#   framework   model  workers  flower_aggr_time     time
# 0    flower  simple        2          0.424407    9.662
# 1    flower  simple        4          0.644229   15.283
# 2    flower  simple        8          0.668994   27.484
# 3    flower  simple       16          2.016466   53.935
# 4    flower  simple       32          2.773877  108.778

# %%
sns.lineplot(df, x="workers", y="time", style="model", hue="framework")
plt.legend(frameon=False)
plt.show()
